# %%
import pandas as pd
dfs = pandas.read_html('https://rate.bot.com.tw/xrt?Lang=zh-TW')

# %%
type(dfs)
# Out:
# list

# %%
len(dfs)
# Out:
# 1

# %%
currency = dfs[0]

# %%
currency = currency.iloc[:,0:5]

# %%
currency.columns = [u'幣別', u'現今匯率-本行買入', u'現今匯率-本行賣出', u'即期匯率-本行買入', u'即期匯率-本行賣出']

# %%
currency
# Out:
#                         幣別 現今匯率-本行買入 現今匯率-本行賣出 即期匯率-本行買入 即期匯率-本行賣出
# 0       美金 (USD)  美金 (USD)     30.04     30.71     30.39     30.49
# 1       港幣 (HKD)  港幣 (HKD)     3.749     3.953     3.875     3.935
# 2       英鎊 (GBP)  英鎊 (GBP)     38.19     40.31     39.19     39.61
# 3       澳幣 (AUD)  澳幣 (AUD)     19.68     20.46     19.95     20.18
# 4   加拿大幣 (CAD)  加拿大幣 (CAD)     22.42     23.33     22.81     23.03
# 5   新加坡幣 (SGD)  新加坡幣 (SGD)     21.12     22.03     21.61     21.79
# 6   瑞士法郎 (CHF)  瑞士法郎 (CHF)     30.22     31.42     30.88     31.17
# 7       日圓 (JPY)  日圓 (JPY)    0.2637    0.2765     0.271     0.275
# 8     南非幣 (ZAR)  南非幣 (ZAR)         -         -     1.972     2.052
# 9     瑞典幣 (SEK)  瑞典幣 (SEK)      2.73      3.25      3.07      3.17
# 10      紐元 (NZD)  紐元 (NZD)     18.73     19.58     19.11     19.31
# 11      泰幣 (THB)  泰幣 (THB)    0.8319    1.0219    0.9443    0.9843
# 12  菲國比索 (PHP)  菲國比索 (PHP)    0.5237    0.6567         -         -
# ...

# %%
currency[u'幣別'] = currency[u'幣別'].str.extract('\((\w+)\)')

# %%
currency
# Out:
#      幣別 現今匯率-本行買入 現今匯率-本行賣出 即期匯率-本行買入 即期匯率-本行賣出
# 0   USD     30.04     30.71     30.39     30.49
# 1   HKD     3.749     3.953     3.875     3.935
# 2   GBP     38.19     40.31     39.19     39.61
# 3   AUD     19.68     20.46     19.95     20.18
# 4   CAD     22.42     23.33     22.81     23.03
# 5   SGD     21.12     22.03     21.61     21.79
# 6   CHF     30.22     31.42     30.88     31.17
# 7   JPY    0.2637    0.2765     0.271     0.275
# 8   ZAR         -         -     1.972     2.052
# 9   SEK      2.73      3.25      3.07      3.17
# 10  NZD     18.73     19.58     19.11     19.31
# 11  THB    0.8319    1.0219    0.9443    0.9843
# 12  PHP    0.5237    0.6567         -         -
# 13  IDR   0.00188   0.00258         -         -
# 14  EUR     32.11     33.45     32.73     33.13
# 15  KRW   0.02323   0.02713         -         -
# 16  VND   0.00094   0.00144         -         -
# 17  MYR     6.094     7.719         -         -
# 18  CNY     4.225     4.387     4.297     4.347

# %%
currency.to_excel(r'C:\Users\smallwind\jupyter_notebook\currency.xlsx')
